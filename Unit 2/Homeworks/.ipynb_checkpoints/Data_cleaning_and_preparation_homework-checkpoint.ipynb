# %%
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the data

# %%
df = pd.read_csv("videosUS.csv")

# %%
df.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0         22.0  2017-11-13T17:13:01.000Z
# 1         24.0  2017-11-13T07:30:00.000Z
# 2         23.0  2017-11-12T19:05:24.000Z
# 3         24.0  2017-11-13T11:00:04.000Z
# 4         24.0  2017-11-12T18:01:41.000Z
#
# ...

# %% [markdown]
# # First question

# %%
df.isna().sum()
# Out:
# video_id                     0
# trending_date              466
# title                      466
# channel_title              466
# category_id                466
# publish_time               466
# tags                       466
# views                      466
# likes                      466
# dislikes                   466
# comment_count              466
# thumbnail_link             466
# comments_disabled          466
# ratings_disabled           466
# video_error_or_removed     466
# description               1036
# dtype: int64

# %% [markdown]
# ## Assumptions about these missing values

# %%
df[df.title.isna()]
# Out:
#                                                 video_id trending_date title  \
# 53     \nSubscribe to WWE on YouTube: http://bit.ly/1...           NaN   NaN
# 54                 \nVisit WWE.com: http://goo.gl/akf0J4           NaN   NaN
# 55     \nMust-See WWE videos on YouTube: https://goo....           NaN   NaN
# 319    \nSubscribe to WWE on YouTube: http://bit.ly/1...           NaN   NaN
# 320                \nVisit WWE.com: http://goo.gl/akf0J4           NaN   NaN
# ...                                                  ...           ...   ...
# 36570  Follow me on Twitter ► https://twitter.com/mar...           NaN   NaN
# 36571  Like me on Facebook ► https://www.facebook.com...           NaN   NaN
# 36572  Join us on Reddit! ► https://www.reddit.com/r/...           NaN   NaN
# 36573  Horror Outro ► https://soundcloud.com/shurkoff...           NaN   NaN
# 36574  Happy Outro ► https://soundcloud.com/hielia/mi...           NaN   NaN
#
# ...

# %% [markdown]
# - As we can see, all the missing values are common to the same videos. Which means that these videos are probably deleted or private maybe. Therefore, they must be deleted from the dataset.
# - For the rest of the missing values in the column description, it is logical to have them, since not all videos must contain a description.

# %% [markdown]
# # Second question

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %% [markdown]
# # Third question

# %% [markdown]
# ## Calculating the z-score :

# %%
df["views_zscore"] = (df.views - df.views.mean()) / df.views.std()
df["likes_zscore"] = (df.likes - df.likes.mean()) / df.likes.std()
df["dislikes_zscore"] = (df.dislikes - df.dislikes.mean()) / df.dislikes.std()
df["comment_count_zscore"] = (df.comment_count - df.comment_count.mean()) / df.comment_count.std()

# keeping only the non-outliers values:
df = df[abs(df["views_zscore"]) < 3]
df = df[abs(df["likes_zscore"]) < 3]
df = df[abs(df["dislikes_zscore"]) < 3]
df = df[abs(df["comment_count_zscore"]) < 3]

df.drop(['views_zscore', 'likes_zscore', 'dislikes_zscore', 'comment_count_zscore'], axis = 1, inplace = True)

# %%
df.count()
# Out:
# video_id                  40086
# trending_date             40086
# title                     40086
# channel_title             40086
# category_id               40086
# publish_time              40086
# tags                      40086
# views                     40086
# likes                     40086
# dislikes                  40086
# comment_count             40086
# thumbnail_link            40086
# comments_disabled         40086
# ratings_disabled          40086
# video_error_or_removed    40086
# description               39527
# dtype: int64

# %% [markdown]
# # Forth question

# %%
print("Unique categories :",df["category_id"].unique())

print("Number of unique categories :",len(df["category_id"].unique()))
# Out:
# Unique categories : [22. 24. 23. 28.  1. 25. 17. 10. 15. 27. 26.  2. 19. 20. 29. 43.]
# Number of unique categories : 16

# %% [markdown]
# # Fifth question

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0         22.0  2017-11-13T17:13:01.000Z
# 1         24.0  2017-11-13T07:30:00.000Z
# 2         23.0  2017-11-12T19:05:24.000Z
# 3         24.0  2017-11-13T11:00:04.000Z
# 4         24.0  2017-11-12T18:01:41.000Z
#
# ...

# %%
df.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# category_id               float64
# publish_time               object
# tags                       object
# views                     float64
# likes                     float64
# dislikes                  float64
# comment_count             float64
# thumbnail_link             object
# comments_disabled          object
# ratings_disabled           object
# video_error_or_removed     object
# description                object
# dtype: object

# %% [markdown]
# ## Answer :
#
# yes, there is some columns that we need to adjust its types :
# - the columns trending_date and publish_time can be of type datetime64.
# - the column category_id needs to be of type int64 or category.
# - the columns views, likes, dislikes, comment_count needs to be of type int64.
# - the columns comments_disabled, ratings_disabled, video_error_or_removed needs to be of type bool.

# %% [markdown]
# # Sixth question

# %%
df.tags.unique()
# Out:
# array(['SHANtell martin',
#        'last week tonight trump presidency|"last week tonight donald trump"|"john oliver trump"|"donald trump"',
#        'racist superman|"rudy"|"mancuso"|"king"|"bach"|"racist"|"superman"|"love"|"rudy mancuso poo bear black white official music video"|"iphone x by pineapple"|"lelepons"|"hannahstocking"|"rudymancuso"|"inanna"|"anwar"|"sarkis"|"shots"|"shotsstudios"|"alesso"|"anitta"|"brazil"|"Getting My Driver\'s License | Lele Pons"',
#        ...,
#        'The Late Late Show|"Late Late Show"|"James Corden"|"Corden"|"late night"|"late night show"|"comedy"|"comedian"|"celebrity"|"celeb"|"celebrities"|"CBS"|"joke"|"jokes"|"funny"|"funny videos"|"funny video"|"humor"|"hollywood"|"famous"|"Drop the Mic"|"Ashton Kutcher"|"Sean Diddy Combs"|"Segment"|"Game"|"Music"|"Recurring"|"Evergreen"',
# ...

# %%
# getting the unique tags
# tags = df.tags.values
tags = df.tags.unique()
all_unique_tags = []
for i in range(0,len(tags)):
    all_unique_tags.extend(tags[i].replace('"','').split("|"))

print('Number of tags is :',len(all_unique_tags))
# Out:
# Number of tags is : 125969

# %%
from collections import Counter

tags = df.tags.values
all_tags = []
for i in range(0,len(tags)):
    all_tags.extend(tags[i].replace('"','').split("|"))

Counter(all_tags).most_common(10)
# Out:
# [('funny', 3582),
#  ('comedy', 2915),
#  ('how to', 1586),
#  ('[none]', 1535),
#  ('music', 1302),
#  ('2018', 1270),
#  ('humor', 1185),
#  ('food', 1152),
#  ('Pop', 1132),
#  ('science', 1111)]
