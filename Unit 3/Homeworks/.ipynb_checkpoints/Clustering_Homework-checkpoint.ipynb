# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./datasets/clustering_data.csv", header=None)
data
# Out:
#              0         1
# 0    -5.462514 -8.113542
# 1    -1.730536  1.619807
# 2    -1.178714  4.515808
# 3    -6.460586 -3.068022
# 4    -1.539308  5.260561
# ...        ...       ...
# 9995 -2.364366  3.486911
# 9996 -4.972361  7.075455
# 9997 -7.344465  7.689617
# 9998 -1.754597 -0.577691
# 9999 -0.939345  1.282297
#
# [10000 rows x 2 columns]

# %%
plt.scatter(data[0],data[1])

# %%
distorsions = []
for i in range(2,20):
    model = KMeans(n_clusters=i)
    model.fit(data)
    distorsions.append(model.inertia_)

plt.figure(figsize=(15,5))
plt.plot(range(2,20),distorsions)
plt.grid(True)

# %%
# The value that represents the elbow is 6
model = KMeans(n_clusters=6, init='random',random_state=1)
model.fit(data)
y_pred = model.predict(data)
plt.scatter(data[0],data[1],c=y_pred)
